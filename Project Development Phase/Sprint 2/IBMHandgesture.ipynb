# %% [markdown]
# # **Convolution Neural Network**

# %%
import tensorflow as tf
print(tf.__version__)
model=tf.keras.Sequential([
                tf.keras.layers.Conv2D(16,(3,3),activation='relu',input_shape=(128,128,1)),
                tf.keras.layers.MaxPooling2D(2,2),
                tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
                tf.keras.layers.MaxPooling2D(2,2),
                tf.keras.layers.Conv2D(16,(3,3),activation='relu'),
                tf.keras.layers.MaxPooling2D(2,2),
                tf.keras.layers.Flatten(),
                tf.keras.layers.Dense(512,activation='relu'),
                tf.keras.layers.Dense(6,activation='softmax')
])
# Out:
# 2.9.2

# %% [markdown]
# # **Data Preprocessing**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.25,zoom_range=0.2,horizontal_flip=True)
train_datagen=ImageDataGenerator(rescale=1./255)
train_gen=train_datagen.flow_from_directory(
    '/content/drive/MyDrive/handgesturedataset/dataset/train',
    target_size=(128,128),
    batch_size=198,
    color_mode='grayscale',
    class_mode='categorical'
)
# Out:
# Found 594 images belonging to 6 classes.

# %% [markdown]
# # **Validation data preprocessing**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
valid_datagen=ImageDataGenerator(rescale=1./255)
valid_gen=valid_datagen.flow_from_directory(
    '/content/drive/MyDrive/handgesturedataset/dataset/test',
    target_size=(128,128),
    batch_size=10,
    color_mode='grayscale',
    class_mode='categorical'
)
# Out:
# Found 30 images belonging to 6 classes.

# %% [markdown]
# # **Loss function and optimizer**

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['Accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_27 (Conv2D)          (None, 126, 126, 16)      160
#
#  max_pooling2d_27 (MaxPoolin  (None, 63, 63, 16)       0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 61, 61, 32)        4640
#
#  max_pooling2d_28 (MaxPoolin  (None, 30, 30, 32)       0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 28, 28, 16)        4624
#
#  max_pooling2d_29 (MaxPoolin  (None, 14, 14, 16)       0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 3136)              0
#
#  dense_18 (Dense)            (None, 512)               1606144
#
#  dense_19 (Dense)            (None, 6)                 3078
#
# =================================================================
# Total params: 1,618,646
# Trainable params: 1,618,646
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Training the model**

# %%
trainmodel=model.fit(
    train_gen,
    steps_per_epoch=3,
    epochs=20,
    validation_data=valid_gen,
    validation_steps=3
)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 8s 2s/step - loss: 1.7905 - Accuracy: 0.1919 - val_loss: 1.6963 - val_Accuracy: 0.3333
# Epoch 2/20
# 3/3 [==============================] - 8s 2s/step - loss: 1.6559 - Accuracy: 0.3148 - val_loss: 1.5365 - val_Accuracy: 0.5667
# Epoch 3/20
# 3/3 [==============================] - 8s 2s/step - loss: 1.4458 - Accuracy: 0.5875 - val_loss: 1.2966 - val_Accuracy: 0.4667
# Epoch 4/20
# 3/3 [==============================] - 8s 2s/step - loss: 1.1411 - Accuracy: 0.6650 - val_loss: 0.9457 - val_Accuracy: 0.7667
# Epoch 5/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.8323 - Accuracy: 0.7761 - val_loss: 0.8660 - val_Accuracy: 0.7000
# Epoch 6/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.6708 - Accuracy: 0.7424 - val_loss: 0.5873 - val_Accuracy: 0.8333
# Epoch 7/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.5720 - Accuracy: 0.7845 - val_loss: 0.6313 - val_Accuracy: 0.7333
# Epoch 8/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.4516 - Accuracy: 0.8316 - val_loss: 0.5314 - val_Accuracy: 0.8333
# Epoch 9/20
# 3/3 [==============================] - 7s 2s/step - loss: 0.3920 - Accuracy: 0.8603 - val_loss: 0.4219 - val_Accuracy: 0.8667
# Epoch 10/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.3269 - Accuracy: 0.8855 - val_loss: 0.4782 - val_Accuracy: 0.7667
# Epoch 11/20
# 3/3 [==============================] - 7s 2s/step - loss: 0.2704 - Accuracy: 0.9242 - val_loss: 0.4599 - val_Accuracy: 0.9000
# Epoch 12/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.2044 - Accuracy: 0.9545 - val_loss: 0.5100 - val_Accuracy: 0.8000
# Epoch 13/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.1722 - Accuracy: 0.9529 - val_loss: 0.4386 - val_Accuracy: 0.8667
# Epoch 14/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.1397 - Accuracy: 0.9731 - val_loss: 0.5392 - val_Accuracy: 0.8000
# Epoch 15/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.1149 - Accuracy: 0.9764 - val_loss: 0.5161 - val_Accuracy: 0.9000
# Epoch 16/20
# 3/3 [==============================] - 7s 2s/step - loss: 0.0908 - Accuracy: 0.9832 - val_loss: 0.4587 - val_Accuracy: 0.9000
# Epoch 17/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.0685 - Accuracy: 0.9916 - val_loss: 0.4552 - val_Accuracy: 0.9333
# Epoch 18/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.0540 - Accuracy: 0.9933 - val_loss: 0.4746 - val_Accuracy: 0.9000
# Epoch 19/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.0422 - Accuracy: 0.9983 - val_loss: 0.4811 - val_Accuracy: 0.9000
# Epoch 20/20
# 3/3 [==============================] - 8s 2s/step - loss: 0.0320 - Accuracy: 1.0000 - val_loss: 0.4718 - val_Accuracy: 0.9000

# %%
import os
os.chdir('/content/drive/MyDrive/')
model.save('./ibmhandgesture.h5')
